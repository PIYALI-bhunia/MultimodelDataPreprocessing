# %% [markdown]
# <a href="https://colab.research.google.com/github/PIYALI-bhunia/MultimodelDataPreprocessing/blob/main/Plot_Multimodal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
w=0.2
x=["TF_IDF","BERT"]
fig = plt.figure(figsize = (8, 6))
RandomForest=[74.46,59.97]
SVM=[48.92,59.54]
ANN=[62.87,58.53]
bar1=np.arange(len(x))
bar2=[i+w for i in bar1]
bar3=[i+w for i in bar2]
plt.bar(bar1,RandomForest,w,label="RandomForest")
plt.bar(bar2,SVM,w,label="SVM")
plt.bar(bar3,ANN,w,label="ANN")

plt.xlabel("models implemented")
plt.ylabel("accuracy")
plt.title('models vs their accuracy in % only for text data')
plt.xticks(bar1+w,x)
plt.legend(loc='upper center')
plt.show()

# %%
w=0.2
x=["MobileNetV2","Resnet_50"]
fig = plt.figure(figsize = (8, 6))
Accuracy=[77.2,67.82]
Val_Accuracy=[75.53,65.33]
bar1=np.arange(len(x))
bar2=[i+w for i in bar1]
plt.bar(bar1,Accuracy,w,label="Accuracy")
plt.bar(bar2,Val_Accuracy,w,label="Validation Accuracy")

plt.xlabel("models implemented")
plt.ylabel("accuracy")
plt.title('models vs their accuracy in % only for image data')
plt.xticks(bar1+w/2,x)
plt.legend(loc='upper center')
plt.show()

# %%
# data={'RandomForest':[74.46,59.97],'SVM':[48.92,59.54],'ANN':[62.87,58.53]}
# df=pd.DataFrame(data,columns=['RandomForest','SVM','ANN'],index=['TF_IDF','BERT'])
# df.plot.barh()
# plt.show()

# %%
# Figure Size
fig, ax = plt.subplots(figsize =(10, 5))
 
# Horizontal Bar Plot
ax.barh(data, columns=['RandomForest','SVM','ANN'],index=['TF_IDF','BERT'])
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('models vs their accuracy in %',
             loc ='left', )
# Show Plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-5e2441f2ef45> in <module>()
#       3
#       4 # Horizontal Bar Plot
# ----> 5 ax.barh(data, columns=['RandomForest','SVM','ANN'],index=['TF_IDF','BERT'])
#       6 # Remove axes splines
#       7 for s in ['top', 'bottom', 'left', 'right']:
#
# TypeError: barh() missing 1 required positional argument: 'width'

# %%
import numpy as np
import matplotlib.pyplot as plt
 
rf_accuracy = 74.46
svm_accuracy = 48.92
ann_accuracy = 62.87
  
# creating the dataset
data = {'Random Forest': rf_accuracy, 'SVM':svm_accuracy, 'ANN':ann_accuracy}


models = list(data.keys())
accuracy = list(data.values())
  
fig = plt.figure(figsize = (8, 4))
 
# creating the bar plot
plt.bar(models, accuracy , color ='maroon',
        width = 0.3)
 
plt.xlabel("models implemented")
plt.ylabel("accuracy")
plt.title("TFIDF - word embedding, (only Text modality)")
plt.show()

# %%
import pandas as pd
from matplotlib import pyplot as plt

models = ['random forest', 'SVM','ANN']
accuracy = [74.46, 48.92,62.87]
 
# Figure Size
fig, ax = plt.subplots(figsize =(10, 5))
 
# Horizontal Bar Plot
ax.barh(models, accuracy)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
 
# Show top values
ax.invert_yaxis()
 
# Add annotation to bars
for i in ax.patches:
    plt.text(i.get_width()+0.2, i.get_y()+0.5,
             str(round((i.get_width()), 2)),
             fontsize = 10, fontweight ='bold',
             color ='grey')
 
# Add Plot Title
ax.set_title('models vs their accuracy in %',
             loc ='left', )
# Show Plot
plt.show()

# %%
rf_accuracy = 59.97
svm_accuracy = 59.54
ann_accuracy = 58.53
  
# creating the dataset
data = {'Random Forest': rf_accuracy, 'SVM':svm_accuracy, 'ANN':ann_accuracy}


models = list(data.keys())
accuracy = list(data.values())
  
fig = plt.figure(figsize = (8, 4))
 
# creating the bar plot
plt.bar(models, accuracy , color ='maroon',
        width = 0.3)
 
plt.xlabel("models implemented")
plt.ylabel("accuracy")
plt.title("BERT - word embedding, (only Text modality)")
plt.show()

# %%
models = ['random forest', 'SVM','ANN']
accuracy = [59.97,59.94,58.53 ]
 
# Figure Size
fig, ax = plt.subplots(figsize =(10, 5))
 
# Horizontal Bar Plot
ax.barh(models, accuracy)
 
# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
    ax.spines[s].set_visible(False)
 
# Remove x, y Ticks
ax.xaxis.set_ticks_position('none')
ax.yaxis.set_ticks_position('none')
 
# Add padding between axes and labels
ax.xaxis.set_tick_params(pad = 5)
ax.yaxis.set_tick_params(pad = 10)
 
# Add x, y gridlines
ax.grid(b = True, color ='grey',
        linestyle ='-.', linewidth = 0.5,
        alpha = 0.2)
